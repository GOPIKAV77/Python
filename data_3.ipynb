# %% [markdown]
# <a href="https://colab.research.google.com/github/GOPIKAV77/Python/blob/main/data_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.DataFrame([[200,"Day 1"],[500,"Day 2"],[300,"Day 3"],[30,"Day 4"],[900,"DAy 5"],[980,"Day 6"],[700,"Day 7"]])

# %% [markdown]
# Number of visitors in a store

# %%
df
# Out:
#      0      1
# 0  200  Day 1
# 1  500  Day 2
# 2  300  Day 3
# 3   30  Day 4
# 4  900  DAy 5
# 5  980  Day 6
# 6  700  Day 7

# %%
df.index = ["1","2","3","4","5","6","7"]
df.columns=["No. of visitors","Day"]
df
# Out:
#    No. of visitors    Day
# 1              200  Day 1
# 2              500  Day 2
# 3              300  Day 3
# 4               30  Day 4
# 5              900  DAy 5
# 6              980  Day 6
# 7              700  Day 7

# %%
df = pd.DataFrame([[200,"Day 1"],[500,"Day 2"],[300,"Day 3"],[30,"Day 4"],[900,"DAy 5"],[980,"Day 6"],[700,"Day 7"]],index = ["1","2","3","4","5","6","7"],columns=["No. of visitors","Day"])

# %%
df["Day"]
# Out:
# 1    Day 1
# 2    Day 2
# 3    Day 3
# 4    Day 4
# 5    DAy 5
# 6    Day 6
# 7    Day 7
# Name: Day, dtype: object

# %%
df.loc["1"]
# Out:
# No. of visitors      200
# Day                Day 1
# Name: 1, dtype: object

# %%
df.loc[["1","2"]]
# Out:
#    No. of visitors    Day
# 1              200  Day 1
# 2              500  Day 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 1 to 7
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No. of visitors  7 non-null      int64
#  1   Day              7 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 468.0+ bytes

# %%
df.dtypes
# Out:
# No. of visitors     int64
# Day                object
# dtype: object

# %%
plt.hist(df["No. of visitors"])
# Out:
# (array([1., 1., 1., 0., 1., 0., 0., 1., 0., 2.]),
#  array([ 30., 125., 220., 315., 410., 505., 600., 695., 790., 885., 980.]),
#  <BarContainer object of 10 artists>)

# %%
sns.barplot(x="Day", y="No. of visitors", hue="Day", data=df)
# Out:
# <Axes: xlabel='Day', ylabel='No. of visitors'>

# %%
import plotly.express as p
p.line(df,x="Day",y="No. of visitors")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Pie(labels= df['Day'],values = df['No. of visitors'],pull=[0.5,0,0,0,0,0.7,0])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
