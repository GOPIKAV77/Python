# %% [markdown]
# <a href="https://colab.research.google.com/github/GOPIKAV77/Python/blob/main/figure_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = y = np.linspace(-5,5,50)

X,Y = np.meshgrid(x,y)

Z = np.sin(X)*np.exp(np.cos(Y**2))

fig,ax = plt.subplots(figsize=(6,5))

n = mpl.colors.Normalize(-abs(Z).max(),abs(Z).max())

p = ax.pcolor(X,Y,Z,norm=n,cmap = mpl.cm.BuPu_r)

ax.axis('tight')

ax.set_xlabel(r"$x-axis$")
ax.set_ylabel(r"$y-axis$")

ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(3))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(3))

c = fig.colorbar(p,ax=ax)

c.set_ticks([-2,-1,0,1,2])
